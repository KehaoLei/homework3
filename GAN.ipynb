# %%
import tensorflow as tf
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets('homework3\MNIST_data')
# Out:
# WARNING:tensorflow:From C:\Users\michaelj\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting homework3\MNIST_data\train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting homework3\MNIST_data\train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting homework3\MNIST_data\t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting homework3\MNIST_data\t10k-labels-idx1-ubyte.gz

# %%
def get_inputs(real_size, noise_size):
    """
    真实图像tensor与噪声图像tensor
    """
    real_img = tf.placeholder(tf.float32, [None, real_size], name='real_img')
    noise_img = tf.placeholder(tf.float32, [None, noise_size], name='noise_img')
    return real_img, noise_img

# %%
def get_generator(noise_img, n_units, out_dim, reuse=False, alpha=0.01):
    """
    生成器
    noise_img: 生成器的输入
    n_units: 隐层单元个数
    out_dim: 生成器输出tensor的size，这里应该为32*32=784
    alpha: leaky ReLU系数
    """
    with tf.variable_scope("generator", reuse=reuse):
        # hidden layer
        hidden1 = tf.layers.dense(noise_img, n_units)
        # leaky ReLU
        hidden1 = tf.maximum(alpha * hidden1, hidden1)
        # dropout
        hidden1 = tf.layers.dropout(hidden1, rate=0.2)

        # logits & outputs
        logits = tf.layers.dense(hidden1, out_dim)
        outputs = tf.tanh(logits)
        
        return logits, outputs

# %%
def get_discriminator(img, n_units, reuse=False, alpha=0.01):
    """
    判别器
    
    n_units: 隐层结点数量
    alpha: Leaky ReLU系数
    """
    
    with tf.variable_scope("discriminator", reuse=reuse):
        # hidden layer
        hidden1 = tf.layers.dense(img, n_units)
        hidden1 = tf.maximum(alpha * hidden1, hidden1)
        
        # logits & outputs
        logits = tf.layers.dense(hidden1, 1)
        outputs = tf.sigmoid(logits)
        
        return logits, outputs

# %%
img_size = mnist.train.images[0].shape[0]
# 传入给generator的噪声size
noise_size = 100
# 生成器隐层参数
g_units = 128
# 判别器隐层参数
d_units = 128
# leaky ReLU的参数
alpha = 0.01

learning_rate = 0.001
# label smoothing
smooth = 0.1

# %%
tf.reset_default_graph()

real_img, noise_img = get_inputs(img_size, noise_size)

# generator
g_logits, g_outputs = get_generator(noise_img, g_units, img_size)

# discriminator
d_logits_real, d_outputs_real = get_discriminator(real_img, d_units)
d_logits_fake, d_outputs_fake = get_discriminator(g_outputs, d_units, reuse=True)
# Out:
# WARNING:tensorflow:From <ipython-input-7-61f994bd1269>:12: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From C:\Users\michaelj\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-7-61f994bd1269>:16: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.

# %%
# discriminator的loss
# 识别真实图片
d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                                     labels=tf.ones_like(d_logits_real)) * (1 - smooth))
# 识别生成的图片
d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                                     labels=tf.zeros_like(d_logits_fake)))
# 总体loss
d_loss = tf.add(d_loss_real, d_loss_fake)

# generator的loss
g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                                labels=tf.ones_like(d_logits_fake)) * (1 - smooth))

# %%
train_vars = tf.trainable_variables()

# generator中的tensor
g_vars = [var for var in train_vars if var.name.startswith("generator")]
# discriminator中的tensor
d_vars = [var for var in train_vars if var.name.startswith("discriminator")]

# optimizer
d_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(d_loss, var_list=d_vars)
g_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(g_loss, var_list=g_vars)

# %%
# batch_size
batch_size = 64
# 训练迭代轮数
epochs = 300
# 抽取样本数
n_sample = 25
# 存储测试样例
samples = []
# 存储loss
losses = []
# 保存生成器变量
saver = tf.train.Saver(var_list = g_vars)
# 开始训练
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for batch_i in range(mnist.train.num_examples//batch_size):
            batch = mnist.train.next_batch(batch_size)
            
            batch_images = batch[0].reshape((batch_size, 784))
            # 对图像像素进行scale，这是因为tanh输出的结果介于(-1,1),real和fake图片共享discriminator的参数
            batch_images = batch_images*2 - 1
            
            # generator的输入噪声
            batch_noise = np.random.uniform(-1, 1, size=(batch_size, noise_size))
            
            # Run optimizers
            _ = sess.run(d_train_opt, feed_dict={real_img: batch_images, noise_img: batch_noise})
            _ = sess.run(g_train_opt, feed_dict={noise_img: batch_noise})
        
        # 每一轮结束计算loss
        train_loss_d = sess.run(d_loss, 
                                feed_dict = {real_img: batch_images, 
                                             noise_img: batch_noise})
        # real img loss
        train_loss_d_real = sess.run(d_loss_real, 
                                     feed_dict = {real_img: batch_images, 
                                                 noise_img: batch_noise})
        # fake img loss
        train_loss_d_fake = sess.run(d_loss_fake, 
                                    feed_dict = {real_img: batch_images, 
                                                 noise_img: batch_noise})
        # generator loss
        train_loss_g = sess.run(g_loss, 
                                feed_dict = {noise_img: batch_noise})
        
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}(Real: {:.4f} + Fake: {:.4f})...".format(train_loss_d, train_loss_d_real, train_loss_d_fake),
              "Generator Loss: {:.4f}".format(train_loss_g))    
        # 记录各类loss值
        losses.append((train_loss_d, train_loss_d_real, train_loss_d_fake, train_loss_g))
        
        # 抽取样本后期进行观察
        sample_noise = np.random.uniform(-1, 1, size=(n_sample, noise_size))
        gen_samples = sess.run(get_generator(noise_img, g_units, img_size, reuse=True),
                               feed_dict={noise_img: sample_noise})
        samples.append(gen_samples)
        
        # 存储checkpoints
        saver.save(sess, './checkpoints/generator.ckpt')

# 将sample的生成数据记录下来
with open('train_samples.pkl', 'wb') as f:
    pickle.dump(samples, f)
# Out:
# Epoch 1/300... Discriminator Loss: 0.0164(Real: 0.0046 + Fake: 0.0118)... Generator Loss: 4.0534
# Epoch 2/300... Discriminator Loss: 0.5151(Real: 0.1718 + Fake: 0.3433)... Generator Loss: 3.8706
# Epoch 3/300... Discriminator Loss: 0.4938(Real: 0.2144 + Fake: 0.2794)... Generator Loss: 3.5330
# Epoch 4/300... Discriminator Loss: 0.3530(Real: 0.0451 + Fake: 0.3078)... Generator Loss: 2.1972
# Epoch 5/300... Discriminator Loss: 1.1609(Real: 0.3350 + Fake: 0.8259)... Generator Loss: 1.8610
# Epoch 6/300... Discriminator Loss: 0.8435(Real: 0.4616 + Fake: 0.3819)... Generator Loss: 2.5847
# Epoch 7/300... Discriminator Loss: 0.7967(Real: 0.4358 + Fake: 0.3609)... Generator Loss: 1.9097
# Epoch 8/300... Discriminator Loss: 0.9113(Real: 0.3816 + Fake: 0.5297)... Generator Loss: 2.1684
# Epoch 9/300... Discriminator Loss: 1.2765(Real: 0.5389 + Fake: 0.7376)... Generator Loss: 2.3378
# Epoch 10/300... Discriminator Loss: 1.1108(Real: 0.6688 + Fake: 0.4419)... Generator Loss: 2.5371
# Epoch 11/300... Discriminator Loss: 1.0280(Real: 0.6509 + Fake: 0.3771)... Generator Loss: 2.6042
# Epoch 12/300... Discriminator Loss: 1.3005(Real: 0.8825 + Fake: 0.4180)... Generator Loss: 1.7341
# Epoch 13/300... Discriminator Loss: 1.2721(Real: 0.6131 + Fake: 0.6590)... Generator Loss: 1.9248
# Epoch 14/300... Discriminator Loss: 0.9745(Real: 0.4854 + Fake: 0.4891)... Generator Loss: 1.6086
# Epoch 15/300... Discriminator Loss: 2.0236(Real: 1.0115 + Fake: 1.0121)... Generator Loss: 1.2403
# Epoch 16/300... Discriminator Loss: 0.9884(Real: 0.2566 + Fake: 0.7318)... Generator Loss: 1.3155
# Epoch 17/300... Discriminator Loss: 1.0071(Real: 0.4630 + Fake: 0.5441)... Generator Loss: 1.7940
# Epoch 18/300... Discriminator Loss: 1.0688(Real: 0.6180 + Fake: 0.4508)... Generator Loss: 1.6818
# Epoch 19/300... Discriminator Loss: 0.8038(Real: 0.2334 + Fake: 0.5705)... Generator Loss: 1.5111
# Epoch 20/300... Discriminator Loss: 0.6441(Real: 0.2908 + Fake: 0.3533)... Generator Loss: 1.9759
# Epoch 21/300... Discriminator Loss: 1.2393(Real: 0.8518 + Fake: 0.3874)... Generator Loss: 1.6751
# Epoch 22/300... Discriminator Loss: 1.0863(Real: 0.6479 + Fake: 0.4384)... Generator Loss: 1.9883
# Epoch 23/300... Discriminator Loss: 1.0104(Real: 0.7243 + Fake: 0.2862)... Generator Loss: 1.9372
# Epoch 24/300... Discriminator Loss: 1.0035(Real: 0.6042 + Fake: 0.3994)... Generator Loss: 2.0816
# Epoch 25/300... Discriminator Loss: 0.8165(Real: 0.4193 + Fake: 0.3971)... Generator Loss: 1.6613
# Epoch 26/300... Discriminator Loss: 1.1311(Real: 0.5499 + Fake: 0.5812)... Generator Loss: 1.6095
# Epoch 27/300... Discriminator Loss: 0.9042(Real: 0.3792 + Fake: 0.5250)... Generator Loss: 1.4595
# Epoch 28/300... Discriminator Loss: 0.8449(Real: 0.4458 + Fake: 0.3991)... Generator Loss: 1.4923
# Epoch 29/300... Discriminator Loss: 0.8091(Real: 0.3577 + Fake: 0.4514)... Generator Loss: 1.8550
# Epoch 30/300... Discriminator Loss: 1.0565(Real: 0.5262 + Fake: 0.5303)... Generator Loss: 1.7209
# Epoch 31/300... Discriminator Loss: 1.1332(Real: 0.6815 + Fake: 0.4517)... Generator Loss: 1.5526
# Epoch 32/300... Discriminator Loss: 0.7366(Real: 0.3242 + Fake: 0.4123)... Generator Loss: 1.5038
# Epoch 33/300... Discriminator Loss: 1.3011(Real: 0.5144 + Fake: 0.7866)... Generator Loss: 0.9506
# Epoch 34/300... Discriminator Loss: 1.0792(Real: 0.5164 + Fake: 0.5628)... Generator Loss: 1.2821
# Epoch 35/300... Discriminator Loss: 1.2370(Real: 0.8072 + Fake: 0.4298)... Generator Loss: 1.9348
# Epoch 36/300... Discriminator Loss: 0.8406(Real: 0.4841 + Fake: 0.3566)... Generator Loss: 1.9203
# Epoch 37/300... Discriminator Loss: 0.7547(Real: 0.3683 + Fake: 0.3864)... Generator Loss: 1.9213
# Epoch 38/300... Discriminator Loss: 0.9292(Real: 0.4401 + Fake: 0.4891)... Generator Loss: 1.5120
# Epoch 39/300... Discriminator Loss: 1.1729(Real: 0.5816 + Fake: 0.5913)... Generator Loss: 1.1094
# Epoch 40/300... Discriminator Loss: 1.1458(Real: 0.3924 + Fake: 0.7534)... Generator Loss: 1.1762
# Epoch 41/300... Discriminator Loss: 1.0576(Real: 0.5608 + Fake: 0.4968)... Generator Loss: 1.4710
# Epoch 42/300... Discriminator Loss: 1.0044(Real: 0.4654 + Fake: 0.5391)... Generator Loss: 1.2821
# Epoch 43/300... Discriminator Loss: 0.9094(Real: 0.4241 + Fake: 0.4853)... Generator Loss: 1.3411
# Epoch 44/300... Discriminator Loss: 0.9113(Real: 0.3167 + Fake: 0.5946)... Generator Loss: 1.4396
# Epoch 45/300... Discriminator Loss: 0.9850(Real: 0.5866 + Fake: 0.3984)... Generator Loss: 1.6284
# Epoch 46/300... Discriminator Loss: 0.6917(Real: 0.3544 + Fake: 0.3373)... Generator Loss: 1.7049
# Epoch 47/300... Discriminator Loss: 0.8228(Real: 0.3761 + Fake: 0.4467)... Generator Loss: 1.3738
# Epoch 48/300... Discriminator Loss: 0.8868(Real: 0.5405 + Fake: 0.3463)... Generator Loss: 1.6859
# Epoch 49/300... Discriminator Loss: 1.0828(Real: 0.6267 + Fake: 0.4561)... Generator Loss: 1.6315
# Epoch 50/300... Discriminator Loss: 0.8842(Real: 0.4790 + Fake: 0.4052)... Generator Loss: 1.6098
# Epoch 51/300... Discriminator Loss: 0.9959(Real: 0.5848 + Fake: 0.4111)... Generator Loss: 1.5215
# Epoch 52/300... Discriminator Loss: 0.7304(Real: 0.3307 + Fake: 0.3997)... Generator Loss: 1.6035
# Epoch 53/300... Discriminator Loss: 1.0718(Real: 0.4172 + Fake: 0.6547)... Generator Loss: 1.1819
# Epoch 54/300... Discriminator Loss: 0.9195(Real: 0.3518 + Fake: 0.5677)... Generator Loss: 1.3144
# Epoch 55/300... Discriminator Loss: 0.9977(Real: 0.3618 + Fake: 0.6358)... Generator Loss: 1.2230
# Epoch 56/300... Discriminator Loss: 0.8851(Real: 0.3603 + Fake: 0.5248)... Generator Loss: 1.3045
# Epoch 57/300... Discriminator Loss: 0.7247(Real: 0.4323 + Fake: 0.2923)... Generator Loss: 1.7579
# Epoch 58/300... Discriminator Loss: 0.8181(Real: 0.3443 + Fake: 0.4738)... Generator Loss: 1.2904
# Epoch 59/300... Discriminator Loss: 0.8583(Real: 0.4683 + Fake: 0.3901)... Generator Loss: 1.6893
# Epoch 60/300... Discriminator Loss: 1.0013(Real: 0.4742 + Fake: 0.5271)... Generator Loss: 1.3630
# Epoch 61/300... Discriminator Loss: 0.9244(Real: 0.3678 + Fake: 0.5566)... Generator Loss: 1.3442
# Epoch 62/300... Discriminator Loss: 0.8810(Real: 0.4282 + Fake: 0.4528)... Generator Loss: 1.4881
# Epoch 63/300... Discriminator Loss: 0.7544(Real: 0.3592 + Fake: 0.3951)... Generator Loss: 1.4862
# Epoch 64/300... Discriminator Loss: 0.8638(Real: 0.4050 + Fake: 0.4589)... Generator Loss: 1.4993
# Epoch 65/300... Discriminator Loss: 0.8682(Real: 0.3833 + Fake: 0.4849)... Generator Loss: 1.5035
# Epoch 66/300... Discriminator Loss: 0.8688(Real: 0.5745 + Fake: 0.2943)... Generator Loss: 1.8750
# Epoch 67/300... Discriminator Loss: 0.9442(Real: 0.4446 + Fake: 0.4996)... Generator Loss: 1.3976
# Epoch 68/300... Discriminator Loss: 0.8538(Real: 0.5356 + Fake: 0.3182)... Generator Loss: 1.8968
# Epoch 69/300... Discriminator Loss: 0.8480(Real: 0.4178 + Fake: 0.4302)... Generator Loss: 1.3992
# Epoch 70/300... Discriminator Loss: 0.8358(Real: 0.4233 + Fake: 0.4125)... Generator Loss: 1.5715
# Epoch 71/300... Discriminator Loss: 0.7287(Real: 0.4552 + Fake: 0.2735)... Generator Loss: 1.9743
# Epoch 72/300... Discriminator Loss: 0.8220(Real: 0.3933 + Fake: 0.4287)... Generator Loss: 1.5907
# Epoch 73/300... Discriminator Loss: 1.0645(Real: 0.5789 + Fake: 0.4856)... Generator Loss: 1.4759
# Epoch 74/300... Discriminator Loss: 0.9253(Real: 0.5126 + Fake: 0.4127)... Generator Loss: 1.5105
# Epoch 75/300... Discriminator Loss: 0.9279(Real: 0.5008 + Fake: 0.4271)... Generator Loss: 1.3951
# Epoch 76/300... Discriminator Loss: 0.8730(Real: 0.2713 + Fake: 0.6017)... Generator Loss: 1.2330
# Epoch 77/300... Discriminator Loss: 0.7710(Real: 0.2709 + Fake: 0.5001)... Generator Loss: 1.3917
# Epoch 78/300... Discriminator Loss: 0.7949(Real: 0.4575 + Fake: 0.3374)... Generator Loss: 1.6015
# Epoch 79/300... Discriminator Loss: 1.0304(Real: 0.6186 + Fake: 0.4118)... Generator Loss: 1.6478
# Epoch 80/300... Discriminator Loss: 0.8658(Real: 0.5617 + Fake: 0.3041)... Generator Loss: 1.8873
# Epoch 81/300... Discriminator Loss: 0.8988(Real: 0.5291 + Fake: 0.3697)... Generator Loss: 1.6602
# Epoch 82/300... Discriminator Loss: 0.8037(Real: 0.4718 + Fake: 0.3319)... Generator Loss: 1.6790
# Epoch 83/300... Discriminator Loss: 0.9919(Real: 0.5332 + Fake: 0.4587)... Generator Loss: 1.3681
# Epoch 84/300... Discriminator Loss: 0.7290(Real: 0.2886 + Fake: 0.4404)... Generator Loss: 1.3165
# Epoch 85/300... Discriminator Loss: 0.9453(Real: 0.5899 + Fake: 0.3554)... Generator Loss: 1.7467
# Epoch 86/300... Discriminator Loss: 0.7189(Real: 0.3877 + Fake: 0.3312)... Generator Loss: 1.6730
# Epoch 87/300... Discriminator Loss: 0.6354(Real: 0.2606 + Fake: 0.3749)... Generator Loss: 1.6695
# Epoch 88/300... Discriminator Loss: 0.8629(Real: 0.4468 + Fake: 0.4160)... Generator Loss: 1.6891
# Epoch 89/300... Discriminator Loss: 0.8568(Real: 0.3327 + Fake: 0.5241)... Generator Loss: 1.3284
# Epoch 90/300... Discriminator Loss: 0.9267(Real: 0.4897 + Fake: 0.4371)... Generator Loss: 1.4632
# Epoch 91/300... Discriminator Loss: 0.8496(Real: 0.4936 + Fake: 0.3560)... Generator Loss: 1.6990
# Epoch 92/300... Discriminator Loss: 0.9962(Real: 0.6545 + Fake: 0.3417)... Generator Loss: 1.7760
# Epoch 93/300... Discriminator Loss: 0.9176(Real: 0.6452 + Fake: 0.2724)... Generator Loss: 1.9771
# Epoch 94/300... Discriminator Loss: 0.8941(Real: 0.4336 + Fake: 0.4605)... Generator Loss: 1.5580
# Epoch 95/300... Discriminator Loss: 1.1309(Real: 0.4826 + Fake: 0.6483)... Generator Loss: 1.0444
# Epoch 96/300... Discriminator Loss: 0.8782(Real: 0.4307 + Fake: 0.4474)... Generator Loss: 1.4622
# Epoch 97/300... Discriminator Loss: 0.8946(Real: 0.5184 + Fake: 0.3763)... Generator Loss: 1.6213
# Epoch 98/300... Discriminator Loss: 0.9507(Real: 0.5312 + Fake: 0.4195)... Generator Loss: 1.5032
# Epoch 99/300... Discriminator Loss: 1.1953(Real: 0.7729 + Fake: 0.4224)... Generator Loss: 1.4629
# Epoch 100/300... Discriminator Loss: 1.0659(Real: 0.6296 + Fake: 0.4363)... Generator Loss: 1.4174
# Epoch 101/300... Discriminator Loss: 1.0812(Real: 0.5752 + Fake: 0.5059)... Generator Loss: 1.2595
# Epoch 102/300... Discriminator Loss: 0.9568(Real: 0.4798 + Fake: 0.4770)... Generator Loss: 1.4813
# Epoch 103/300... Discriminator Loss: 0.9924(Real: 0.5362 + Fake: 0.4562)... Generator Loss: 1.3829
# Epoch 104/300... Discriminator Loss: 1.0161(Real: 0.5687 + Fake: 0.4474)... Generator Loss: 1.3796
# Epoch 105/300... Discriminator Loss: 0.9568(Real: 0.5285 + Fake: 0.4284)... Generator Loss: 1.3785
# Epoch 106/300... Discriminator Loss: 0.9905(Real: 0.3766 + Fake: 0.6140)... Generator Loss: 1.1677
# Epoch 107/300... Discriminator Loss: 1.1149(Real: 0.6432 + Fake: 0.4718)... Generator Loss: 1.4523
# Epoch 108/300... Discriminator Loss: 0.7628(Real: 0.4026 + Fake: 0.3602)... Generator Loss: 1.6907
# Epoch 109/300... Discriminator Loss: 0.8368(Real: 0.4547 + Fake: 0.3821)... Generator Loss: 1.5473
# Epoch 110/300... Discriminator Loss: 0.9137(Real: 0.2908 + Fake: 0.6228)... Generator Loss: 1.0584
# Epoch 111/300... Discriminator Loss: 1.1468(Real: 0.3101 + Fake: 0.8367)... Generator Loss: 0.9637
# Epoch 112/300... Discriminator Loss: 0.9609(Real: 0.5230 + Fake: 0.4379)... Generator Loss: 1.4405
# Epoch 113/300... Discriminator Loss: 1.1382(Real: 0.5745 + Fake: 0.5637)... Generator Loss: 1.3645
# Epoch 114/300... Discriminator Loss: 0.8164(Real: 0.3687 + Fake: 0.4477)... Generator Loss: 1.4593
# Epoch 115/300... Discriminator Loss: 1.2446(Real: 0.7264 + Fake: 0.5182)... Generator Loss: 1.1988
# Epoch 116/300... Discriminator Loss: 1.1428(Real: 0.6687 + Fake: 0.4741)... Generator Loss: 1.3460
# Epoch 117/300... Discriminator Loss: 1.2462(Real: 0.6293 + Fake: 0.6169)... Generator Loss: 1.1044
# Epoch 118/300... Discriminator Loss: 0.9147(Real: 0.5208 + Fake: 0.3939)... Generator Loss: 1.5014
# Epoch 119/300... Discriminator Loss: 0.8070(Real: 0.4507 + Fake: 0.3563)... Generator Loss: 1.5956
# Epoch 120/300... Discriminator Loss: 0.8285(Real: 0.4930 + Fake: 0.3355)... Generator Loss: 1.4337
# Epoch 121/300... Discriminator Loss: 0.8870(Real: 0.4485 + Fake: 0.4386)... Generator Loss: 1.4055
# Epoch 122/300... Discriminator Loss: 0.7902(Real: 0.4074 + Fake: 0.3827)... Generator Loss: 1.4417
# Epoch 123/300... Discriminator Loss: 0.7681(Real: 0.4115 + Fake: 0.3566)... Generator Loss: 1.6109
# Epoch 124/300... Discriminator Loss: 1.0097(Real: 0.4645 + Fake: 0.5452)... Generator Loss: 1.3251
# Epoch 125/300... Discriminator Loss: 1.0070(Real: 0.5528 + Fake: 0.4542)... Generator Loss: 1.3562
# Epoch 126/300... Discriminator Loss: 0.8443(Real: 0.5110 + Fake: 0.3333)... Generator Loss: 1.7215
# Epoch 127/300... Discriminator Loss: 0.8973(Real: 0.4441 + Fake: 0.4532)... Generator Loss: 1.6377
# Epoch 128/300... Discriminator Loss: 0.9119(Real: 0.3159 + Fake: 0.5960)... Generator Loss: 1.1975
# Epoch 129/300... Discriminator Loss: 1.0591(Real: 0.4723 + Fake: 0.5868)... Generator Loss: 1.1657
# Epoch 130/300... Discriminator Loss: 0.9648(Real: 0.5477 + Fake: 0.4172)... Generator Loss: 1.4700
# Epoch 131/300... Discriminator Loss: 0.9818(Real: 0.5725 + Fake: 0.4093)... Generator Loss: 1.5729
# Epoch 132/300... Discriminator Loss: 1.0078(Real: 0.4453 + Fake: 0.5626)... Generator Loss: 1.3490
# Epoch 133/300... Discriminator Loss: 0.8323(Real: 0.4430 + Fake: 0.3892)... Generator Loss: 1.4244
# Epoch 134/300... Discriminator Loss: 1.0430(Real: 0.5251 + Fake: 0.5179)... Generator Loss: 1.2602
# Epoch 135/300... Discriminator Loss: 1.0791(Real: 0.5125 + Fake: 0.5666)... Generator Loss: 1.1738
# Epoch 136/300... Discriminator Loss: 1.1424(Real: 0.4414 + Fake: 0.7010)... Generator Loss: 0.9502
# Epoch 137/300... Discriminator Loss: 0.8160(Real: 0.4025 + Fake: 0.4134)... Generator Loss: 1.4672
# Epoch 138/300... Discriminator Loss: 0.8165(Real: 0.4640 + Fake: 0.3525)... Generator Loss: 1.6457
# Epoch 139/300... Discriminator Loss: 1.0409(Real: 0.4332 + Fake: 0.6077)... Generator Loss: 1.1536
# Epoch 140/300... Discriminator Loss: 0.9831(Real: 0.5023 + Fake: 0.4808)... Generator Loss: 1.3993
# Epoch 141/300... Discriminator Loss: 1.2014(Real: 0.4849 + Fake: 0.7165)... Generator Loss: 1.0032
# Epoch 142/300... Discriminator Loss: 0.8739(Real: 0.4382 + Fake: 0.4357)... Generator Loss: 1.6612
# Epoch 143/300... Discriminator Loss: 1.1194(Real: 0.5897 + Fake: 0.5297)... Generator Loss: 1.2520
# Epoch 144/300... Discriminator Loss: 0.9143(Real: 0.5151 + Fake: 0.3992)... Generator Loss: 1.4371
# Epoch 145/300... Discriminator Loss: 0.9716(Real: 0.5496 + Fake: 0.4219)... Generator Loss: 1.3352
# Epoch 146/300... Discriminator Loss: 0.9763(Real: 0.6255 + Fake: 0.3508)... Generator Loss: 1.4683
# Epoch 147/300... Discriminator Loss: 1.0351(Real: 0.5557 + Fake: 0.4794)... Generator Loss: 1.2412
# Epoch 148/300... Discriminator Loss: 0.9918(Real: 0.5104 + Fake: 0.4814)... Generator Loss: 1.2546
# Epoch 149/300... Discriminator Loss: 1.0867(Real: 0.5891 + Fake: 0.4976)... Generator Loss: 1.3250
# Epoch 150/300... Discriminator Loss: 0.9567(Real: 0.4652 + Fake: 0.4916)... Generator Loss: 1.2372
# Epoch 151/300... Discriminator Loss: 0.8031(Real: 0.3086 + Fake: 0.4945)... Generator Loss: 1.2447
# Epoch 152/300... Discriminator Loss: 1.0697(Real: 0.4064 + Fake: 0.6633)... Generator Loss: 1.0768
# Epoch 153/300... Discriminator Loss: 0.9719(Real: 0.4555 + Fake: 0.5164)... Generator Loss: 1.2081
# Epoch 154/300... Discriminator Loss: 0.9688(Real: 0.5241 + Fake: 0.4447)... Generator Loss: 1.2256
# Epoch 155/300... Discriminator Loss: 0.9310(Real: 0.3277 + Fake: 0.6033)... Generator Loss: 1.1768
# Epoch 156/300... Discriminator Loss: 1.0232(Real: 0.5422 + Fake: 0.4810)... Generator Loss: 1.3691
# Epoch 157/300... Discriminator Loss: 0.8864(Real: 0.4165 + Fake: 0.4699)... Generator Loss: 1.4150
# Epoch 158/300... Discriminator Loss: 0.9025(Real: 0.3300 + Fake: 0.5725)... Generator Loss: 1.1335
# Epoch 159/300... Discriminator Loss: 0.8128(Real: 0.4105 + Fake: 0.4022)... Generator Loss: 1.5899
# Epoch 160/300... Discriminator Loss: 0.8610(Real: 0.4935 + Fake: 0.3675)... Generator Loss: 1.5533
# Epoch 161/300... Discriminator Loss: 1.0522(Real: 0.4631 + Fake: 0.5891)... Generator Loss: 1.2153
# Epoch 162/300... Discriminator Loss: 1.0887(Real: 0.4601 + Fake: 0.6286)... Generator Loss: 1.1350
# Epoch 163/300... Discriminator Loss: 1.1223(Real: 0.5437 + Fake: 0.5786)... Generator Loss: 1.0840
# Epoch 164/300... Discriminator Loss: 0.8391(Real: 0.3431 + Fake: 0.4960)... Generator Loss: 1.2711
# Epoch 165/300... Discriminator Loss: 1.2413(Real: 0.4480 + Fake: 0.7933)... Generator Loss: 0.9071
# Epoch 166/300... Discriminator Loss: 0.9740(Real: 0.3188 + Fake: 0.6552)... Generator Loss: 1.0638
# Epoch 167/300... Discriminator Loss: 0.9384(Real: 0.4259 + Fake: 0.5125)... Generator Loss: 1.2733
# Epoch 168/300... Discriminator Loss: 0.8797(Real: 0.4076 + Fake: 0.4722)... Generator Loss: 1.3612
# Epoch 169/300... Discriminator Loss: 0.9897(Real: 0.4483 + Fake: 0.5414)... Generator Loss: 1.1794
# Epoch 170/300... Discriminator Loss: 0.9092(Real: 0.6149 + Fake: 0.2943)... Generator Loss: 1.6612
# Epoch 171/300... Discriminator Loss: 1.0130(Real: 0.4585 + Fake: 0.5544)... Generator Loss: 1.2026
# Epoch 172/300... Discriminator Loss: 1.0329(Real: 0.5005 + Fake: 0.5324)... Generator Loss: 1.2175
# Epoch 173/300... Discriminator Loss: 0.9945(Real: 0.4411 + Fake: 0.5533)... Generator Loss: 1.2676
# Epoch 174/300... Discriminator Loss: 0.9126(Real: 0.5303 + Fake: 0.3823)... Generator Loss: 1.5061
# Epoch 175/300... Discriminator Loss: 0.9541(Real: 0.5963 + Fake: 0.3578)... Generator Loss: 1.6538
# Epoch 176/300... Discriminator Loss: 0.8193(Real: 0.3913 + Fake: 0.4281)... Generator Loss: 1.3882
# Epoch 177/300... Discriminator Loss: 1.0700(Real: 0.5122 + Fake: 0.5577)... Generator Loss: 1.2453
# Epoch 178/300... Discriminator Loss: 1.0903(Real: 0.6842 + Fake: 0.4061)... Generator Loss: 1.3107
# Epoch 179/300... Discriminator Loss: 0.9232(Real: 0.4850 + Fake: 0.4382)... Generator Loss: 1.3954
# Epoch 180/300... Discriminator Loss: 0.8261(Real: 0.4573 + Fake: 0.3688)... Generator Loss: 1.6353
# Epoch 181/300... Discriminator Loss: 0.8152(Real: 0.3903 + Fake: 0.4249)... Generator Loss: 1.2404
# Epoch 182/300... Discriminator Loss: 0.9196(Real: 0.5710 + Fake: 0.3486)... Generator Loss: 1.6672
# Epoch 183/300... Discriminator Loss: 0.9908(Real: 0.5623 + Fake: 0.4285)... Generator Loss: 1.3961
# Epoch 184/300... Discriminator Loss: 0.9032(Real: 0.3888 + Fake: 0.5144)... Generator Loss: 1.2050
# Epoch 185/300... Discriminator Loss: 0.9728(Real: 0.5111 + Fake: 0.4618)... Generator Loss: 1.3400
# Epoch 186/300... Discriminator Loss: 1.1361(Real: 0.6571 + Fake: 0.4790)... Generator Loss: 1.4328
# Epoch 187/300... Discriminator Loss: 1.0543(Real: 0.5449 + Fake: 0.5095)... Generator Loss: 1.3816
# Epoch 188/300... Discriminator Loss: 0.8470(Real: 0.4800 + Fake: 0.3670)... Generator Loss: 1.6763
# Epoch 189/300... Discriminator Loss: 0.8106(Real: 0.4177 + Fake: 0.3929)... Generator Loss: 1.3731
# Epoch 190/300... Discriminator Loss: 1.1169(Real: 0.4572 + Fake: 0.6597)... Generator Loss: 1.0919
# Epoch 191/300... Discriminator Loss: 1.1942(Real: 0.5282 + Fake: 0.6660)... Generator Loss: 1.0762
# Epoch 192/300... Discriminator Loss: 0.7388(Real: 0.4140 + Fake: 0.3247)... Generator Loss: 1.6393
# Epoch 193/300... Discriminator Loss: 0.9738(Real: 0.5143 + Fake: 0.4595)... Generator Loss: 1.2927
# Epoch 194/300... Discriminator Loss: 1.0596(Real: 0.4839 + Fake: 0.5756)... Generator Loss: 1.2166
# Epoch 195/300... Discriminator Loss: 0.8966(Real: 0.3329 + Fake: 0.5637)... Generator Loss: 1.1374
# Epoch 196/300... Discriminator Loss: 0.8782(Real: 0.5039 + Fake: 0.3743)... Generator Loss: 1.6187
# Epoch 197/300... Discriminator Loss: 1.0029(Real: 0.4063 + Fake: 0.5966)... Generator Loss: 1.0824
# Epoch 198/300... Discriminator Loss: 0.9093(Real: 0.4982 + Fake: 0.4112)... Generator Loss: 1.3945
# Epoch 199/300... Discriminator Loss: 0.9018(Real: 0.5030 + Fake: 0.3988)... Generator Loss: 1.4535
# Epoch 200/300... Discriminator Loss: 0.9378(Real: 0.5488 + Fake: 0.3891)... Generator Loss: 1.5685
# Epoch 201/300... Discriminator Loss: 0.8808(Real: 0.4899 + Fake: 0.3909)... Generator Loss: 1.5127
# Epoch 202/300... Discriminator Loss: 0.7909(Real: 0.3597 + Fake: 0.4312)... Generator Loss: 1.3600
# Epoch 203/300... Discriminator Loss: 0.9301(Real: 0.4690 + Fake: 0.4611)... Generator Loss: 1.3586
# Epoch 204/300... Discriminator Loss: 1.1718(Real: 0.5429 + Fake: 0.6288)... Generator Loss: 1.1635
# Epoch 205/300... Discriminator Loss: 1.1710(Real: 0.6590 + Fake: 0.5120)... Generator Loss: 1.3492
# Epoch 206/300... Discriminator Loss: 1.0449(Real: 0.4605 + Fake: 0.5844)... Generator Loss: 1.1537
# Epoch 207/300... Discriminator Loss: 0.9320(Real: 0.5029 + Fake: 0.4290)... Generator Loss: 1.4962
# Epoch 208/300... Discriminator Loss: 1.0528(Real: 0.4837 + Fake: 0.5691)... Generator Loss: 1.2491
# Epoch 209/300... Discriminator Loss: 0.9364(Real: 0.5204 + Fake: 0.4160)... Generator Loss: 1.5761
# Epoch 210/300... Discriminator Loss: 0.9683(Real: 0.5493 + Fake: 0.4190)... Generator Loss: 1.3901
# Epoch 211/300... Discriminator Loss: 1.0713(Real: 0.5548 + Fake: 0.5165)... Generator Loss: 1.1801
# Epoch 212/300... Discriminator Loss: 0.8958(Real: 0.5176 + Fake: 0.3782)... Generator Loss: 1.5200
# Epoch 213/300... Discriminator Loss: 0.8374(Real: 0.3978 + Fake: 0.4397)... Generator Loss: 1.2714
# Epoch 214/300... Discriminator Loss: 0.7531(Real: 0.3978 + Fake: 0.3553)... Generator Loss: 1.5560
# Epoch 215/300... Discriminator Loss: 0.7772(Real: 0.4514 + Fake: 0.3258)... Generator Loss: 1.5829
# Epoch 216/300... Discriminator Loss: 0.9200(Real: 0.5586 + Fake: 0.3615)... Generator Loss: 1.5153
# Epoch 217/300... Discriminator Loss: 0.9041(Real: 0.4111 + Fake: 0.4930)... Generator Loss: 1.3149
# Epoch 218/300... Discriminator Loss: 1.0497(Real: 0.5914 + Fake: 0.4583)... Generator Loss: 1.3983
# Epoch 219/300... Discriminator Loss: 0.9921(Real: 0.5934 + Fake: 0.3987)... Generator Loss: 1.4777
# Epoch 220/300... Discriminator Loss: 0.9434(Real: 0.4651 + Fake: 0.4783)... Generator Loss: 1.4735
# Epoch 221/300... Discriminator Loss: 0.9401(Real: 0.5248 + Fake: 0.4153)... Generator Loss: 1.3929
# Epoch 222/300... Discriminator Loss: 1.0556(Real: 0.5144 + Fake: 0.5412)... Generator Loss: 1.1694
# Epoch 223/300... Discriminator Loss: 1.0041(Real: 0.3432 + Fake: 0.6609)... Generator Loss: 1.0358
# Epoch 224/300... Discriminator Loss: 0.9726(Real: 0.4904 + Fake: 0.4822)... Generator Loss: 1.3668
# Epoch 225/300... Discriminator Loss: 1.1274(Real: 0.6294 + Fake: 0.4980)... Generator Loss: 1.2959
# Epoch 226/300... Discriminator Loss: 0.9989(Real: 0.3360 + Fake: 0.6629)... Generator Loss: 0.9956
# Epoch 227/300... Discriminator Loss: 0.9542(Real: 0.6036 + Fake: 0.3506)... Generator Loss: 1.7589
# Epoch 228/300... Discriminator Loss: 1.0374(Real: 0.5809 + Fake: 0.4565)... Generator Loss: 1.4705
# Epoch 229/300... Discriminator Loss: 0.9099(Real: 0.3534 + Fake: 0.5565)... Generator Loss: 1.1817
# Epoch 230/300... Discriminator Loss: 0.8167(Real: 0.2814 + Fake: 0.5353)... Generator Loss: 1.3097
# Epoch 231/300... Discriminator Loss: 1.0009(Real: 0.4943 + Fake: 0.5067)... Generator Loss: 1.1516
# Epoch 232/300... Discriminator Loss: 1.0153(Real: 0.5553 + Fake: 0.4600)... Generator Loss: 1.3918
# Epoch 233/300... Discriminator Loss: 1.1331(Real: 0.4836 + Fake: 0.6495)... Generator Loss: 1.1126
# Epoch 234/300... Discriminator Loss: 0.9858(Real: 0.4412 + Fake: 0.5447)... Generator Loss: 1.1732
# Epoch 235/300... Discriminator Loss: 0.9441(Real: 0.5102 + Fake: 0.4339)... Generator Loss: 1.3118
# Epoch 236/300... Discriminator Loss: 0.8247(Real: 0.3342 + Fake: 0.4905)... Generator Loss: 1.4384
# Epoch 237/300... Discriminator Loss: 0.8323(Real: 0.2743 + Fake: 0.5579)... Generator Loss: 1.1992
# Epoch 238/300... Discriminator Loss: 1.0419(Real: 0.7496 + Fake: 0.2923)... Generator Loss: 1.6861
# Epoch 239/300... Discriminator Loss: 0.8808(Real: 0.4863 + Fake: 0.3945)... Generator Loss: 1.5271
# Epoch 240/300... Discriminator Loss: 1.0874(Real: 0.5152 + Fake: 0.5721)... Generator Loss: 1.1076
# Epoch 241/300... Discriminator Loss: 0.7718(Real: 0.4250 + Fake: 0.3468)... Generator Loss: 1.6441
# Epoch 242/300... Discriminator Loss: 1.0988(Real: 0.6222 + Fake: 0.4766)... Generator Loss: 1.2722
# Epoch 243/300... Discriminator Loss: 0.9508(Real: 0.5321 + Fake: 0.4186)... Generator Loss: 1.5652
# Epoch 244/300... Discriminator Loss: 0.9089(Real: 0.4933 + Fake: 0.4157)... Generator Loss: 1.3736
# Epoch 245/300... Discriminator Loss: 0.9142(Real: 0.4589 + Fake: 0.4554)... Generator Loss: 1.3847
# Epoch 246/300... Discriminator Loss: 0.8751(Real: 0.4964 + Fake: 0.3788)... Generator Loss: 1.5046
# Epoch 247/300... Discriminator Loss: 0.9997(Real: 0.4521 + Fake: 0.5476)... Generator Loss: 1.3231
# Epoch 248/300... Discriminator Loss: 1.0181(Real: 0.5928 + Fake: 0.4253)... Generator Loss: 1.3130
# Epoch 249/300... Discriminator Loss: 1.0688(Real: 0.6282 + Fake: 0.4407)... Generator Loss: 1.3240
# Epoch 250/300... Discriminator Loss: 1.0071(Real: 0.4607 + Fake: 0.5464)... Generator Loss: 1.2280
# Epoch 251/300... Discriminator Loss: 0.8862(Real: 0.5080 + Fake: 0.3782)... Generator Loss: 1.5081
# Epoch 252/300... Discriminator Loss: 0.9829(Real: 0.5746 + Fake: 0.4083)... Generator Loss: 1.3912
# Epoch 253/300... Discriminator Loss: 1.1386(Real: 0.6859 + Fake: 0.4527)... Generator Loss: 1.4484
# Epoch 254/300... Discriminator Loss: 1.1187(Real: 0.6305 + Fake: 0.4881)... Generator Loss: 1.5303
# Epoch 255/300... Discriminator Loss: 0.9017(Real: 0.5477 + Fake: 0.3540)... Generator Loss: 1.6320
# Epoch 256/300... Discriminator Loss: 1.0020(Real: 0.5277 + Fake: 0.4743)... Generator Loss: 1.2092
# Epoch 257/300... Discriminator Loss: 0.8454(Real: 0.4377 + Fake: 0.4076)... Generator Loss: 1.6301
# Epoch 258/300... Discriminator Loss: 0.9003(Real: 0.3875 + Fake: 0.5127)... Generator Loss: 1.3233
# Epoch 259/300... Discriminator Loss: 1.1680(Real: 0.6650 + Fake: 0.5031)... Generator Loss: 1.1713
# Epoch 260/300... Discriminator Loss: 0.8476(Real: 0.3926 + Fake: 0.4550)... Generator Loss: 1.2603
# Epoch 261/300... Discriminator Loss: 0.9759(Real: 0.5194 + Fake: 0.4564)... Generator Loss: 1.4452
# Epoch 262/300... Discriminator Loss: 0.8531(Real: 0.3103 + Fake: 0.5428)... Generator Loss: 1.2520
# Epoch 263/300... Discriminator Loss: 0.8375(Real: 0.3859 + Fake: 0.4515)... Generator Loss: 1.3151
# Epoch 264/300... Discriminator Loss: 0.8613(Real: 0.5422 + Fake: 0.3191)... Generator Loss: 1.6523
# Epoch 265/300... Discriminator Loss: 0.8102(Real: 0.3792 + Fake: 0.4310)... Generator Loss: 1.4254
# Epoch 266/300... Discriminator Loss: 0.8912(Real: 0.5447 + Fake: 0.3465)... Generator Loss: 1.4837
# Epoch 267/300... Discriminator Loss: 0.9439(Real: 0.4545 + Fake: 0.4894)... Generator Loss: 1.3654
# Epoch 268/300... Discriminator Loss: 1.0108(Real: 0.5350 + Fake: 0.4759)... Generator Loss: 1.2982
# Epoch 269/300... Discriminator Loss: 1.1777(Real: 0.5410 + Fake: 0.6367)... Generator Loss: 1.0354
# Epoch 270/300... Discriminator Loss: 0.8718(Real: 0.5011 + Fake: 0.3707)... Generator Loss: 1.5056
# Epoch 271/300... Discriminator Loss: 0.9310(Real: 0.4424 + Fake: 0.4886)... Generator Loss: 1.2452
# Epoch 272/300... Discriminator Loss: 0.9103(Real: 0.5203 + Fake: 0.3900)... Generator Loss: 1.6417
# Epoch 273/300... Discriminator Loss: 0.8933(Real: 0.4717 + Fake: 0.4216)... Generator Loss: 1.3738
# Epoch 274/300... Discriminator Loss: 1.0934(Real: 0.5879 + Fake: 0.5054)... Generator Loss: 1.1660
# Epoch 275/300... Discriminator Loss: 1.0654(Real: 0.5249 + Fake: 0.5406)... Generator Loss: 1.3136
# Epoch 276/300... Discriminator Loss: 0.8912(Real: 0.3174 + Fake: 0.5738)... Generator Loss: 1.2659
# Epoch 277/300... Discriminator Loss: 1.0983(Real: 0.6186 + Fake: 0.4797)... Generator Loss: 1.1768
# Epoch 278/300... Discriminator Loss: 0.8817(Real: 0.5519 + Fake: 0.3298)... Generator Loss: 1.7680
# Epoch 279/300... Discriminator Loss: 0.8253(Real: 0.5391 + Fake: 0.2862)... Generator Loss: 1.8635
# Epoch 280/300... Discriminator Loss: 0.9348(Real: 0.3623 + Fake: 0.5725)... Generator Loss: 1.1735
# Epoch 281/300... Discriminator Loss: 1.0429(Real: 0.4584 + Fake: 0.5845)... Generator Loss: 1.3389
# Epoch 282/300... Discriminator Loss: 0.9322(Real: 0.4243 + Fake: 0.5080)... Generator Loss: 1.2589
# Epoch 283/300... Discriminator Loss: 0.8852(Real: 0.4100 + Fake: 0.4752)... Generator Loss: 1.2592
# Epoch 284/300... Discriminator Loss: 1.0398(Real: 0.3453 + Fake: 0.6945)... Generator Loss: 0.9806
# Epoch 285/300... Discriminator Loss: 1.1088(Real: 0.6186 + Fake: 0.4903)... Generator Loss: 1.4150
# Epoch 286/300... Discriminator Loss: 0.9098(Real: 0.3816 + Fake: 0.5282)... Generator Loss: 1.3295
# Epoch 287/300... Discriminator Loss: 1.1012(Real: 0.5584 + Fake: 0.5428)... Generator Loss: 1.1608
# Epoch 288/300... Discriminator Loss: 0.9096(Real: 0.4737 + Fake: 0.4359)... Generator Loss: 1.5087
# Epoch 289/300... Discriminator Loss: 0.8934(Real: 0.3900 + Fake: 0.5034)... Generator Loss: 1.2122
# Epoch 290/300... Discriminator Loss: 0.8546(Real: 0.5174 + Fake: 0.3372)... Generator Loss: 1.7131
# Epoch 291/300... Discriminator Loss: 1.0879(Real: 0.5643 + Fake: 0.5235)... Generator Loss: 1.2596
# Epoch 292/300... Discriminator Loss: 1.0069(Real: 0.5362 + Fake: 0.4707)... Generator Loss: 1.4306
# Epoch 293/300... Discriminator Loss: 0.8625(Real: 0.5361 + Fake: 0.3264)... Generator Loss: 1.8203
# Epoch 294/300... Discriminator Loss: 0.8255(Real: 0.4382 + Fake: 0.3874)... Generator Loss: 1.5126
# Epoch 295/300... Discriminator Loss: 0.9294(Real: 0.2847 + Fake: 0.6446)... Generator Loss: 1.1696
# Epoch 296/300... Discriminator Loss: 1.0520(Real: 0.5379 + Fake: 0.5141)... Generator Loss: 1.1753
# Epoch 297/300... Discriminator Loss: 0.9637(Real: 0.2076 + Fake: 0.7561)... Generator Loss: 0.9218
# Epoch 298/300... Discriminator Loss: 1.0782(Real: 0.5601 + Fake: 0.5181)... Generator Loss: 1.2898
# Epoch 299/300... Discriminator Loss: 0.9277(Real: 0.6140 + Fake: 0.3137)... Generator Loss: 1.7539
# Epoch 300/300... Discriminator Loss: 0.8547(Real: 0.3481 + Fake: 0.5066)... Generator Loss: 1.1602

# %%
fig, ax = plt.subplots(figsize=(20,7))
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator Total Loss')
plt.plot(losses.T[1], label='Discriminator Real Loss')
plt.plot(losses.T[2], label='Discriminator Fake Loss')
plt.plot(losses.T[3], label='Generator')
plt.title("Training Losses")
plt.legend()

# %%
# Load samples from generator taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pickle.load(f)

# %%
def view_samples(epoch, samples):
    """
    epoch代表第几次迭代的图像
    samples为我们的采样结果
    """
    fig, axes = plt.subplots(figsize=(7,7), nrows=5, ncols=5, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch][1]): # 这里samples[epoch][1]代表生成的图像结果，而[0]代表对应的logits
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
# 加载生成器变量
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    sample_noise = np.random.uniform(-1, 1, size=(25, noise_size))
    gen_samples = sess.run(get_generator(noise_img, g_units, img_size, reuse=True),
                           feed_dict={noise_img: sample_noise})
# Out:
# WARNING:tensorflow:From C:\Users\michaelj\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from checkpoints\generator.ckpt

# %%
_ = view_samples(-1, samples) # 显示最后一轮的outputs

# %%
# 指定要查看的轮次
epoch_idx = [0, 5, 10, 20, 40, 60, 80, 100, 150, 250] # 一共300轮
show_imgs = []
for i in epoch_idx:
    show_imgs.append(samples[i][1])

# %%
# 指定图片形状
rows, cols = 10, 25
fig, axes = plt.subplots(figsize=(30,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

idx = range(0, epochs, int(epochs/rows))

for sample, ax_row in zip(show_imgs, axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %%
# 加载我们的生成器变量
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    sample_noise = np.random.uniform(-1, 1, size=(25, noise_size))
    gen_samples = sess.run(get_generator(noise_img, g_units, img_size, reuse=True),
                           feed_dict={noise_img: sample_noise})
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\generator.ckpt

# %%
_ = view_samples(0, [gen_samples])
